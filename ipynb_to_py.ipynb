# %% [markdown]
# Reinstall all modules
# - import pandas / conda install pandas
# - import os
# - import socket
# - import subprocess
# - import datetime
# - import subprocess
# - import datetime
# - import time
# - import random
# - import steamlit
# - import PyPDF2
# - import tabula
# - import pdfminer
# - import camelot
# - import ipython /  pip install ipython
# - import nbconvert

# %% [markdown]
# - altair                        4.2.0
# - anaconda-client               1.9.0
# - anaconda-navigator            2.1.4
# anyio                         3.6.1
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# attrs                         21.4.0
# Automat                       20.2.0
# Babel                         2.10.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# bleach                        5.0.0
# blinker                       1.4
# brotlipy                      0.7.0
# cachetools                    5.0.0
# camelot-py                    0.10.1
# certifi                       2021.10.8
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# clyent                        1.2.2
# conda                         4.12.0
# conda-build                   3.21.5
# conda-content-trust           0+unknown
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cryptography                  3.4.8
# cssselect                     1.1.0
# decorator                     5.1.1
# defusedxml                    0.7.1
# distro                        1.7.0
# entrypoints                   0.4
# executing                     0.8.3
# fastjsonschema                2.15.3
# filelock                      3.6.0
# flit_core                     3.7.1
# future                        0.18.2
# ghostscript                   0.7
# gitdb                         4.0.9
# GitPython                     3.1.27
# glob2                         0.7
# hyperlink                     21.0.0
# idna                          3.3
# incremental                   21.3.0
# ipykernel                     5.5.5
# ipython                       8.3.0
# ipython-genutils              0.2.0
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# jedi                          0.18.1
# Jinja2                        3.1.2
# jmespath                      0.10.0
# json5                         0.9.5
# jsonschema                    4.4.0
# jupyter-client                7.0.6
# jupyter-core                  4.10.0
# jupyter-server                1.17.0
# jupyter-server-mathjax        0.2.5
# jupyterlab                    3.4.2
# jupyterlab-pygments           0.2.2
# jupyterlab-server             2.13.0
# libarchive-c                  2.9
# lxml                          4.8.0
# MarkupSafe                    2.1.1
# matplotlib-inline             0.1.3
# mistune                       0.8.4
# navigator-updater             0.2.1
# nbclassic                     0.3.7
# nbclient                      0.5.13
# nbconvert                     6.5.0
# nbdime                        3.1.1
# nbformat                      5.4.0
# nest-asyncio                  1.5.5
# notebook                      6.4.11
# notebook-shim                 0.1.0
# opencv-python                 4.5.5.64
# packaging                     21.3
# pandocfilters                 1.5.0
# parsel                        1.6.0
# parso                         0.8.3
# pdfminer                      20191125
# pdfminer.six                  20220319
# pdftopng                      0.2.3
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           21.2.4
# pkginfo                       1.8.2
# plotly                        5.6.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.29
# Protego                       0.1.16
# protobuf                      3.20.0
# psutil                        5.8.0
# psycopg2                      2.8.6
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# pyarrow                       7.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycosat                       0.6.3
# pycparser                     2.21
# pycryptodome                  3.14.1
# pydeck                        0.7.1
# PyDispatcher                  2.0.5
# Pygments                      2.12.0
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# Pympler                       1.0.1
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# PyPDF2                        1.27.9
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# python-dateutil               2.8.2
# pytz                          2021.3
# pytz-deprecation-shim         0.1.0.post0
# PyYAML                        6.0
# pyzmq                         19.0.2
# QtPy                          2.0.1
# queuelib                      1.5.0
# requests                      2.27.1
# requests-file                 1.5.1
# ruamel-yaml-conda             0.15.100
# Scrapy                        2.6.1
# selenium                      3.141.0
# semver                        2.13.0
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    61.2.0
# sip                           4.19.13
# six                           1.16.0
# smmap                         5.0.0
# sniffio                       1.2.0
# soupsieve                     2.3.1
# stack-data                    0.2.0
# streamlit                     1.8.1
# tabula                        1.0.5
# tabula-py                     2.3.0
# tabulate                      0.8.9
# tenacity                      8.0.1
# terminado                     0.13.3
# testpath                      0.6.0
# tinycss2                      1.1.1
# tldextract                    3.2.0
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# Twisted                       22.2.0
# typing_extensions             4.1.1
# tzdata                        2022.1
# tzlocal                       4.2
# ujson                         5.1.0
# urllib3                       1.26.9
# validators                    0.18.2
# w3lib                         1.21.0
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.3.2
# wheel                         0.37.1
# zope.interface                5.4.0

# %% [markdown]
# # 1) Convert ipynb to .py format

# %%
import pandas as pd
import nbconvert

# %%
# =======================================================================================
# Use the command line
# =======================================================================================

# Define your path
cd ~/Documents/Python/Data/
# Convert ipynd files to  .py files
jupyter nbconvert --to script Test1.ipynb Test2.ipynb
# or 
#jupyter nbconvert --to script *.ipynb  # for all .ipynb files in the selected folder
# Out:
# [NbConvertApp] Converting notebook Test1.ipynb to script
# [NbConvertApp] Writing 339 bytes to Test1.py
# ['#!/usr/bin/env python\n', '# coding: utf-8\n', '\n', '# In[2]:\n', '\n', '\n', 'import pandas as pd\n', '\n', '\n', '# In[ ]:\n', '\n', '\n', 'print("Done")\n', '\n', '\n', '# # Comment\n', '\n', '# In[12]:\n', '\n', '\n', 'def divide(x, y):\n', '   try:\n', '       result = x / y\n', '   except ZeroDivisionError:\n', '       break\n', '   else:\n', '       print("result is", result)\n', '   \n', '   print("executing finally clause")\n', '\n', '\n', '# In[11]:\n', '\n', '\n', 'divide(2,3)\n', '\n', '\n', '# In[ ]:\n', '\n', '\n', '\n', '\n']

# %%
cd ~/Documents/Python/Data/
# Convert ipynd files to  .py files
jupyter nbconvert --to script Switch_IP.ipynb
# Out:
#   Input In [122]
#     cd ~/Documents/Python/Data/
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# yfinanceyfinance# 2) IP changing

# %% [markdown]
# ## a) Curent path and folder selection

# %%
import pandas as pd
import os
cwd = os.getcwd()
print(cwd)
# Print the current working directory
print("Current working directory: {0}".format(cwd))

sector='Data/Equity'
#Navigate to Strings directory
newPath = os.path.join(cwd, sector) +'/'

print(sector[:2])


df=pd.read_csv(newPath+'/'+'United States.csv')
print(df)
# Out:
# /home/frederic/Documents/Python
# Current working directory: /home/frederic/Documents/Python
# Da
#      ticker                         name country ExtractionDate
# 0      AAPL                   Apple Inc.       U     2022-04-15
# 1      MSFT        Microsoft Corporation       U     2022-04-15
# 2      GOOG                Alphabet Inc.       U     2022-04-15
# 3     GOOGL                Alphabet Inc.       U     2022-04-15
# 4      AMZN             Amazon.com, Inc.       U     2022-04-15
# ...     ...                          ...     ...            ...
# 6653   CBNK        Capital Bancorp, Inc.       U     2022-04-15
# 6654   ITHX      ITHAX Acquisition Corp.       U     2022-04-15
# 6655  SEOVF                Sernova Corp.       U     2022-04-15
# 6656   ALCO                  Alico, Inc.       U     2022-04-15
# 6657   AKTS  Akoustis Technologies, Inc.       U     2022-04-15
#
# [6658 rows x 4 columns]

# %% [markdown]
# ## b) First runs

# %%
import socket
s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
s.connect(("8.8.8.8", 80))
print(s.getsockname()[0])
# Out:
# 192.168.1.16

# %% [markdown]
# ## c) Second run

# %% [markdown]
# Source: https://medium.com/@jiurdqe/rotate-ip-adress-in-python-with-protonvpn-f474a9b2b74a

# %%
import subprocess
import datetime
from time import sleep

def switch_ip():
    command = "sudo protonvpn c -r"
    proc = subprocess.Popen(command, shell=True, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    
while True:
    now = datetime.datetime.now()
    if now.minute == 0:
        switch_ip()
    
    sleep(55)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14335/991199985.py in <module>
#      11     if now.minute == 0:
#      12         switch_ip()
# ---> 13     sleep(55)
#
# KeyboardInterrupt:

# %%
import pandas as pd

# %%
# Collect country list from Cyberghost VPN
dg=pd.read_csv(r'/home/frederic/Programms/CyberghostVPN/cyberghostvpn_country.csv', sep=";", encoding='utf8', index_col=0)
'''
df=dg.drop(dg.columns[[0, 3]], axis = 1, inplace = True)
'''
print(dg)
Country=dg[dg.columns[1]]
Country.replace(" ", "") # Delete spoace in the country codes

for i in range (0,5):
    print(random.choice(list(Country)))
# Out:
#             Country Name      CountryCode
#  No.
# 1             Andorra                  AD
# 2       United Arab Emirates           AE
# 3             Albania                  AL
# 4             Armenia                  AM
# 5            Argentina                 AR
# ...                       ...         ...
# 87            Ukraine                  UA
# 88         United States               US
# 89           Venezuela                 VE
# 90            Vietnam                  VN
# 91          South Africa               ZA
#
# [91 rows x 2 columns]
# KR
# GR
# AM
# CR
# BY

# %% [markdown]
# ### 1) Switch country

# %%
import os
import subprocess
from subprocess import Popen, PIPE
import datetime
from time import sleep
import random
import socket
import numpy as np

# %%
def switch_ip(ctry):
    
    print(ctry)
    
    dg=pd.read_csv(r'/home/frederic/Programms/CyberghostVPN/cyberghostvpn_ctry_city.csv', sep=";", encoding='utf8', index_col=0)
    dg[dg['country']==ctry]
    #Country=random.choice(list(dg[dg.columns[1]]))

    Country=dg[dg.columns[1]]
    
    #if now.minute == 0:
    ctry_city=random.choice(list(ctry))
    
    # Code preparation
    sudo_password='7S4VBRyA@'
    instruct= 'cyberghostvpn --traffic --country-code ' + ctry + ' --connect'
    command =instruct.split()
    
    # Launch command panel
    p = Popen(['sudo', '-S'] + command, stdin=PIPE, stderr=PIPE, universal_newlines=True)
    print(p)
    sudo_prompt = p.communicate(sudo_password + '\n')[1]


    # Print IP adress
    s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
    s.connect(("8.8.8.8", 80))
    print(s.getsockname()[0])

# %%
while True:
    now = datetime.datetime.now()
    print(now, now.minute)
    # Country list
    dg=pd.read_csv(r'/home/frederic/Programms/CyberghostVPN/cyberghostvpn_country.csv', sep=";", encoding='utf8', index_col=0)
    Country=dg[dg.columns[1]]
    
    #if now.minute == 0:
    ctry=random.choice(list(Country))
    switch_ip(ctry)
    sleep(55)
# Out:
# 2022-05-03 18:01:51.875688 1
# BA
# <Popen: returncode: None args: ['sudo', '-S', 'cyberghostvpn', '--traffic', ...>
# Prepare OpenVPN connection ...
# Select server ... travnik-s401-i03
# Connecting ...
# VPN connection established.
# 10.3.4.60
# 2022-05-03 18:02:55.835388 2
# NZ
# <Popen: returncode: None args: ['sudo', '-S', 'cyberghostvpn', '--traffic', ...>
# Prepare OpenVPN connection ...
# Select server ... auckland-s401-i08
# Connecting ...
# OpenVPN process found, terminating all OpenVPN process ...
# All OpenVPN processes are terminated!
# VPN connection established.
# 10.8.4.249
# 2022-05-03 18:04:05.386648 4
# MY
# <Popen: returncode: None args: ['sudo', '-S', 'cyberghostvpn', '--traffic', ...>
# Prepare OpenVPN connection ...
# Select server ... kualalumpur-s403-i01
# Connecting ...
# OpenVPN process found, terminating all OpenVPN process ...
# All OpenVPN processes are terminated!
# VPN connection established.
# 10.1.4.229
# 2022-05-03 18:05:21.810290 5
# AE
# ...

# %% [markdown]
# ### 2) Switch city

# %%
def switch_ip_city(ctry):
    
    print(ctry)
    
    # Code preparation
    sudo_password='7S4VBRyA@'
    instruct= 'cyberghostvpn --traffic --country-code ' + ctry # + ' --connect'
    sudo cyberghostvpn --traffic --country-code US --city "New York"
    command =instruct.split()
    
    # Launch command panel
    #proc = subprocess.Popen(command, shell=True, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    #sudo_prompt = proc.communicate(sudo_password + '\n')

    p = Popen(['sudo', '-S'] + command, stdin=PIPE, stderr=PIPE, universal_newlines=True)
    print(p)
    sudo_prompt = p.communicate(sudo_password + '\n')[1]
    print(sudo_prompt)


    # Print IP adress
    s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
    s.connect(("8.8.8.8", 80))
    print(s.getsockname()[0])

# %% [markdown]
# # Collect all countries and cities from CyberGhost VPN

# %%
# Creation of the full list of countries and cities from CyberGhost VPN
import pandas as pd

dg=pd.read_csv(r'/home/frederic/Programms/CyberghostVPN/cyberghostvpn_country.csv', sep=";", encoding='utf8', index_col=0)
#Country=random.choice(list(dg[dg.columns[1]]))
Country=dg[dg.columns[1]]


for ctry in Country:
    print('country ',ctry)
    sleep(45)
    List_DF.append(str(df_ctry))
    # Code preparation
    sudo_password='7S4VBRyA@'
    #instruct= 'cyberghostvpn --traffic --country-code ' + ctry # + ' --connect'
    instruct='cyberghostvpn --traffic --country-code ' + ctry
    command =instruct.split()

    # Launch command panel
    p = Popen(['sudo', '-S'] + command, stdin=PIPE, stderr=PIPE, stdout=PIPE,universal_newlines=True)
    #text = p.stdout.read()
    #print(p.communicate())
    #rint(text)
    sudo_prompt = p.communicate(sudo_password + '\n')#[1] 
    #df=pd.DataFrame(sudo_prompt[0])
    cty_txt=sudo_prompt[0].split('|')
    print(sudo_prompt[0])


    List_=[cty_txt[index] for index in range(7,len(cty_txt),5)]
    print(List_)
    dg=pd.DataFrame(List_, columns =['city'])
    dg['country']=ctry
        
    df=pd.concat([df,dg],ignore_index=True)
    df.to_csv(r'/home/frederic/Programms/CyberghostVPN/cyberghostvpn_ctry_city.csv')

#df=[pd.concat(dfi) for i in range(0,len(Country))] 
#dh = pd.concat(List_DF)


print(len(df))
# Out:
# country  AD
# +-----+---------+----------+------+
# | No. |   City  | Instance | Load |
# +-----+---------+----------+------+
# |  1  | Andorra |    48    | 68%  |
# +-----+---------+----------+------+
#
# [' Andorra ']
# country  AE
# +-----+-------+----------+------+
# | No. |  City | Instance | Load |
# +-----+-------+----------+------+
# |  1  | Dubai |    12    | 61%  |
# +-----+-------+----------+------+
#
# [' Dubai ']
# country  AL
# +-----+--------+----------+------+
# | No. |  City  | Instance | Load |
# +-----+--------+----------+------+
# |  1  | Tirana |    34    | 59%  |
# +-----+--------+----------+------+
#
# [' Tirana ']
# country  AM
# +-----+---------+----------+------+
# | No. |   City  | Instance | Load |
# +-----+---------+----------+------+
# |  1  | Yerevan |    26    | 74%  |
# +-----+---------+----------+------+
#
# [' Yerevan ']
# country  AR
# +-----+--------------+----------+------+
# | No. |     City     | Instance | Load |
# ...

# %% [markdown]
# # Drop duplicates

# %%
# Drop duplicates
dg=pd.read_csv(r'/home/frederic/Programms/CyberghostVPN/cyberghostvpn_ctry_city.csv', sep=",", encoding='utf8', index_col=0)
dg=dg.drop_duplicates(ignore_index=True)
print(type(dg))
dg.to_csv(r'/home/frederic/Programms/CyberghostVPN/cyberghostvpn_ctry_city.csv')
len(dg)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 114
